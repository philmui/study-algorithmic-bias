# %% [markdown]
# # Exploring Relationships between US Election & COVID-19
#
# We have all been impacted by the pandemic this past year.
#
# Are there correlation between political beliefs and how we are impacted by COVID-19?  We use a proxy of political beliefs by using the recent presidential election by state, and infer if there is reason to believe that there are differential impact of COVID-19 to Americans.
#
# The data used in this notebook is taken as a snapshot right after the November 2020 election.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import ssl

ssl._create_default_https_context = ssl._create_unverified_context
plt.rcParams['figure.figsize'] = (12,10)
plt.rcParams['font.size'] = 14
plt.style.use("fivethirtyeight")
# %matplotlib inline

# %% [markdown]
# ## Data Sources
#
# Source: https://www.nbcnews.com/politics/2020-elections/president-results
#
# Date: November 14, 2020

# %%
presidential_results = "../data/us-presidential-results-2020.csv"

presidential_data = pd.read_csv(presidential_results,
                               index_col="state",
                               thousands=",")
presidential_data.dtypes
# Out:
# biden    int64
# trump    int64
# dtype: object

# %%
presidential_data.tail(5)
# Out:
#                  biden    trump
# state
# Virginia       2413317  1962708
# Washington     2356584  1572345
# West Virginia   235657   544826
# Wisconsin      1630619  1610073
# Wyoming          73491   193559

# %%
presidential_data['voters'] = presidential_data.trump + presidential_data.biden
presidential_data['trump_pct'] = 100*presidential_data.trump / presidential_data.voters
presidential_data.head()
# Out:
#                biden    trump    voters  trump_pct
# state
# Alabama       843473  1434159   2277632  62.967108
# Alaska        143037   179080    322117  55.594706
# Arizona      1672054  1661677   3333731  49.844364
# Arkansas      419258   758183   1177441  64.392441
# California  10760110  5750654  16510764  34.829727

# %% [markdown]
# ## COVID-19 Data
#
# Source: https://covid.cdc.gov/covid-data-tracker/#cases_casesper100klast7days
#
# Date: November 14, 2020

# %%
covid_raw_cases = "../data/us-covid-11-14-2020.csv"

covid_data = pd.read_csv(covid_raw_cases, skiprows=3)
covid_data.rename(columns= { "State/Territory" : "state",
                             "Total Cases" : "cases",
                             "Case Rate per 100000" : "case_rate",
                             "Case Rate per 100000 in Last 7 Days" : "case_rate_7days"
                           },
                  inplace=True)
covid_data.shape
# Out:
# (61, 13)

# %%
covid_data.head(5)
# Out:
#             state   cases  Confirmed Cases  Probable Cases  \
# 0          Alaska   22405              NaN             NaN
# 1         Alabama  213617         180275.0         33342.0
# 2        Arkansas  130318              NaN             NaN
# 3  American Samoa       3              NaN             NaN
# 4         Arizona  269577         262454.0          7123.0
#
#    Cases in Last 7 Days  case_rate  Total Deaths  Confirmed Deaths  \
# 0                  4808       3038            97               NaN
# 1                 12903       4370          3231            2989.0
# 2                 11088       4324          2148               NaN
# 3                     3          5             0               NaN
# 4                 14813       3759          6257            5806.0
#
#    Probable Deaths  Deaths in Last 7 Days  Death Rate per 100000  \
# 0              NaN                     13                     13
# 1            242.0                    182                     66
# 2              NaN                     92                     71
# 3              NaN                      0                      0
# 4            451.0                    148                     87
#
#    case_rate_7days  Death Rate per 100K in Last 7 Days
# 0             93.1                                 0.3
# 1             37.7                                 0.5
# 2             52.6                                 0.4
# 3              0.8                                 0.0
# 4             29.5                                 0.3

# %%
covid_data = covid_data[["state", "cases", "case_rate", "case_rate_7days"]]
covid_data.head()
# Out:
#             state   cases  case_rate  case_rate_7days
# 0          Alaska   22405       3038             93.1
# 1         Alabama  213617       4370             37.7
# 2        Arkansas  130318       4324             52.6
# 3  American Samoa       3          5              0.8
# 4         Arizona  269577       3759             29.5

# %% [markdown]
# ## Merging Voting data + COVID-19 data

# %%
data = presidential_data.join(covid_data.set_index('state'), on="state", how="inner")

# %%
data.dtypes
# Out:
# biden                int64
# trump                int64
# voters               int64
# trump_pct          float64
# cases                int64
# case_rate            int64
# case_rate_7days    float64
# dtype: object

# %%
data
# Out:
#                          biden    trump    voters  trump_pct    cases  \
# state
# Alabama                 843473  1434159   2277632  62.967108   213617
# Alaska                  143037   179080    322117  55.594706    22405
# Arizona                1672054  1661677   3333731  49.844364   269577
# Arkansas                419258   758183   1177441  64.392441   130318
# California            10760110  5750654  16510764  34.829727   998502
# Colorado               1803873  1364160   3168033  43.060158   154038
# Connecticut            1080387   714973   1795360  39.823378    88645
# Delaware                296268   200603    496871  40.373256    28016
# District of Columbia    307265    18172    325437   5.583876    18666
# Florida                5294767  5667474  10962241  51.699958   858585
# Georgia                2472182  2458010   4930192  49.856273   419870
# Hawaii                  366070   196800    562870  34.963668    16274
# Idaho                   287031   554128    841159  65.876725    79798
# Illinois               3398423  2420846   5819269  41.600517   551957
# Indiana                1241503  1729110   2970613  58.207178   236565
# Iowa                    758416   897149   1655565  54.189899   176695
# Kansas                  551199   753370   1304569  57.748574   115507
# Kentucky                772223  1326347   2098570  63.202419   132844
# Louisiana               856034  1255776   2111810  59.464440   201981
# Maine                   420357   341949    762306  44.857183     8791
# Maryland               1875270   951838   2827108  33.668257   164090
# Massachusetts          2271849  1131115   3402964  33.239112   187523
# Michigan               2795975  2648577   5444552  48.646372   268362
# Minnesota              1718739  1485345   3204084  46.357867   207339
# Mississippi             491224   731049   1222273  59.810615   133340
# Missouri               1242851  1711848   2954699  57.936460   235722
# Montana                 244783   343590    588373  58.396629    44244
# Nebraska                371918   553781    925699  59.823009    94922
# Nevada                  703486   669890   1373376  48.776883   116737
# New Hampshire           424937   365660    790597  46.251124    13929
# New Jersey             2410404  1752127   4162531  42.092828   270383
# New Mexico              499782   401361    901143  44.539102    62006
# New York               3777598  2876104   6653702  43.225621   272361
# North Carolina         2681124  2754822   5435946  50.677876   305233
# North Dakota            114901   235585    350486  67.216665    62872
# Ohio                   2603677  3074400   5678077  54.145092   282528
# Oklahoma                503890  1020280   1524170  66.940039   158451
# Oregon                 1333467   952435   2285902  41.665609    54937
# Pennsylvania           3417479  3351976   6769455  49.516187   254387
# Rhode Island            306192   199830    506022  39.490378    41529
# South Carolina         1091541  1385103   2476644  55.926609   192101
# South Dakota            150471   261043    411514  63.434780    62327
# Tennessee              1139376  1849820   2989196  61.883530   300458
# Texas                  5218943  5866019  11084962  52.918711  1004983
# Utah                    554028   848863   1402891  60.508122   145789
# Vermont                 242841   112591    355432  31.677227     2743
# Virginia               2413317  1962708   4376025  44.851389   200800
# Washington             2356584  1572345   3928929  40.019685   125498
# West Virginia           235657   544826    780483  69.806261    31639
# Wisconsin              1630619  1610073   3240692  49.683000   318023
# Wyoming                  73491   193559    267050  72.480434    21341
#
#                       case_rate  case_rate_7days
# state
# Alabama                    4370             37.7
# Alaska                     3038             93.1
# Arizona                    3759             29.5
# Arkansas                   4324             52.6
# California                 2524             17.1
# Colorado                   2704             74.2
# Connecticut                2481             42.1
# Delaware                   2897             26.0
# District of Columbia       2657             17.8
# Florida                    4031             24.9
# Georgia                    3991             67.6
# Hawaii                     1146              6.9
# Idaho                      4549             72.4
# Illinois                   4332             96.9
# Indiana                    3535             76.3
# Iowa                       5598            144.8
# Kansas                     3967             87.7
# Kentucky                   2973             49.0
# Louisiana                  4334             31.5
# Maine                       657             12.7
# Maryland                   2716             26.4
# Massachusetts              2717             30.8
# Michigan                   2687             65.6
# Minnesota                  3695             94.3
# Mississippi                4465             35.7
# Missouri                   3848             71.5
# Montana                    4165             84.7
# Nebraska                   4920            105.4
# Nevada                     3847             46.2
# New Hampshire              1027             20.2
# New Jersey                 3035             33.7
# New Mexico                 2959             65.5
# New York                   2444             24.4
# North Carolina             2940             22.9
# North Dakota               8272            181.7
# Ohio                       2417             51.8
# Oklahoma                   4018             73.4
# Oregon                     1311             21.6
# Pennsylvania               1986             34.0
# Rhode Island               3928             69.6
# South Carolina             3778             25.9
# South Dakota               7065            156.9
# Tennessee                  4438             57.6
# Texas                      3502             31.1
# Utah                       4612             83.7
# Vermont                     438              9.5
# Virginia                   2357             16.7
# Washington                 1665             21.3
# West Virginia              1752             36.0
# Wisconsin                  5470            118.1
# Wyoming                    3694            122.1

# %% [markdown]
# ## Visualizing

# %%
data.plot(kind='scatter', x='trump_pct', y='cases', alpha=0.5)

# %%
data.plot(kind='scatter', x='trump_pct', y='case_rate', alpha=0.5)

# %%
data.plot(kind='scatter', x='trump_pct', y='case_rate_7days', alpha=0.5)

# %%
# plotting a regression line
sns.lmplot(x='trump_pct', y='case_rate_7days', data=data, aspect=1.6, scatter_kws={'alpha':0.2});
plt.title("COVID Cases per 100,000 in the last 7 days & Trump Vote%")
plt.xlabel("Percentage of Trump Vote in 2020")
plt.ylabel("COVID Cases per 100,000 in week of 11/14/2020")
# Out:
# Text(1.6750000000000043, 0.5, 'COVID Cases per 100,000 in week of 11/14/2020')

# %% [markdown]
# ## Linear Regression in sklearn

# %%
# single variable linear regression
feature_cols = ['trump_pct']
X = data[feature_cols]
y = data.case_rate_7days

X.head()
# Out:
#             trump_pct
# state
# Alabama     62.967108
# Alaska      55.594706
# Arizona     49.844364
# Arkansas    64.392441
# California  34.829727

# %% [markdown]
# ### sklearn 4-steps ML¶

# %%
# Step 1: Import the model class

from sklearn.linear_model import LinearRegression

# %%
# Step 2: Instantiate the estimator

model = LinearRegression()

# %%
# Step 3: Fit the model with data (training)

model.fit(X,y)
# Out:
# LinearRegression()

# %%
# Step 4: Predict response for new inputs

print(f"0%: {model.predict([[0.0]])}")
print(f"50%: {model.predict([[50.0]])}")
print(f"100%: {model.predict([[100.0]])}")
# Out:
# 0%: [-24.86911891]
# 50%: [56.09133016]
# 100%: [137.05177922]

# %% [markdown]
# Let's look at the _intercept_ and _coeff_ : bring back the algebra!

# %%
print("intercept: {0}, coeff: {1}".
      format(model.intercept_, model.coef_))
# Out:
# intercept: -24.86911891182465, coeff: [1.61920898]

# %% [markdown]
# Recall that each model always contains some amount of random irreducible error $\epsilon$. So, given a prediction $\hat{y}$, the actual $y = \hat{y} + \epsilon$. Below, we will assume $y$ is exactly linear.
#
# - We are often taught the formula for a line is: $y = mx + b$.
# - Note this can alternatively be written: $y = \beta_0 + \beta_1 x$.
#
# Interpreting the intercept ($\beta_0$):
#
# - It is the value of $y$ when all independent variables are 0.
# - Here, it is the estimated # COVID-19 cases per 100,000 when the Trump vote percentage is 0.
# - **Note:** It does not always make sense to interpret the intercept. (Why?)
#
# Interpreting the "trump_pct" coefficient ($\beta_1$):
#
# - **Interpretation:** An increase of 1 percentage for Trump is _associated with_ increasing the number of cases per 100,000 people in the state population by $\beta_1$.
# - Here, a Trump vote percentage increase of 1 % in a state is _associated with_ an increase of 1.6 COVID-19 cases per 100,000 people in the state population.
# - This is not a statement of causation.
# - $\beta_1$ would be **negative** if an increase in Trump vote percentage was associated with a **decrease** in # COVID-19 cases per 100,000 population.
# - $\beta_1$ would be **zero** if Trump vote percentage is not associated with COVID-19 cases per 100,000 population.
#
# ---
#
# ---
#
# Here, we will generalize this to $n$ independent variables as follows:
#
# $y = \beta_0 + \beta_1x_1 + \beta_2x_2 + ... + \beta_nx_n + \epsilon$
#
# - $y$ is the response.
# - $\beta_0$ is the intercept.
# - $\beta_1$ is the coefficient for $x_1$ (the first feature).
# - $\beta_n$ is the coefficient for $x_n$ (the nth feature).
# - $\epsilon$ is the _error_ term
#
# This equation is still called **linear** because the highest degree of the independent variables (e.g. $x_i$) is 1. Note that because the $\beta$ values are constants, they will not be independent variables in the final model, as seen above.
#
#
# ---
#
# The $\beta$ values are called the **model coefficients**:
#
# - These values are estimated (or "learned") during the model fitting process using the **least squares criterion**.
# - Specifically, we are trying to find the line (mathematically) that minimizes the **sum of squared residuals** (or "sum of squared errors").
# - Once we've learned these coefficients, we can use the model to predict the response.
#
# ![Estimating coefficients](./images/estimating_coefficients.png)
#
# In the diagram above:
#
# - The black dots are the **observed values** of x and y.
# - The blue line is our **least squares line**.
# - The red lines are the **residuals**, which are the vertical distances between the observed values and the least squares line.

# %% [markdown]
# ### Consider these 3 predictions again:

# %%
print(f"0%: {model.predict([[0.0]])}")
print(f"50%: {model.predict([[50.0]])}")
print(f"100%: {model.predict([[100.0]])}")
# Out:
# 0%: [-24.86911891]
# 50%: [56.09133016]
# 100%: [137.05177922]
